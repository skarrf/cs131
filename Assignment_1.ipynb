# %% [markdown]
# # Instructions
#
# * Make a copy of this colab.
# * Add code where needed.
# * Execute all cells, save colab with output.
# * Submit your .ipynb file to canvas

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %% [markdown]
# ## Problem 1 - IsPalindrome - 15 points
#
#
# Write a function to check if a given string is a palindrome and test it on the given input.

# %%
def IsPalindrome(s: str) -> bool:
  # Update this code
  # return False

  if (len(s) <= 1):
    return True

  stack = []
  n = int(len(s) / 2)

  # stack half the string
  for i in range (0, n):
    stack.append(s[i : i + 1])

  # pop and compare with the next half of letters
  for i in range (0, n):
    if (stack.pop() != s[n + i : n + i + 1]):
      return False
  return True

# %%
# DO NOT MODIFY THIS CELL, BUT DO EXECUTE THIS CELL

a = ['', 'a', 'aa', 'abba', 'abab', 'abca']
expected = [True, True, True, True, False, False]

for ix, s in enumerate(a):
  b = IsPalindrome(s)
  print(s, '->IsPalindrom->', b)
  assert b == expected[ix]
# Out:
#  ->IsPalindrom-> True
# a ->IsPalindrom-> True
# aa ->IsPalindrom-> True
# abba ->IsPalindrom-> True
# abab ->IsPalindrom-> False
# abca ->IsPalindrom-> False

# %% [markdown]
# # Problem 2 - FlipSort - 20 points
#
# Use the function `FlipPrefix()` given below that can flip a prefix an array to sort the array in increasing order. You can compare array elements but the only way to modify the array is to use `FlipPrefix()`. You may want to use NumPy's `argmax()` function.

# %%
# DO NOT MODIFY THIS CELL, BUT DO EXECUTE THIS CELL

def FlipPrefix(a: list[int], before_n: int) -> list[int]:
  assert 0 < before_n <= len(a)
  b = a[:before_n]
  return b[::-1] + a[before_n:]

# %%
def FlipSort(a: list[int]) -> list[int]:
  # Update this code using FlipPrefix and argmax
  # return a
  # argmax gets the index of the biggest number in the list

  n = len(a)

  if (len(a) <= 1):
    return a

  for i in range(0, n):
    while(np.argmax(a[0 : n - i]) != n - i - 1): # while 3!= 5 - 0 - 1
      a = FlipPrefix(a, np.argmax(a[0 : n - i]) + 1) # 31254 -> 52134
      a = FlipPrefix(a, n - i) # 52134 -> 43125
      # print(a)
  return a

# %%
# DO NOT MODIFY THIS CELL, BUT DO EXECUTE THIS CELL

a = [[3, 1, 2, 5, 4],
     [1],
     [100, 101, 51, 41, 31, 21, 11, 1]]

for row in a:
  b = FlipSort(row)
  print(row, '->FlipSort->', b)
  assert b == sorted(row)
# Out:
# [3, 1, 2, 5, 4] ->FlipSort-> [1, 2, 3, 4, 5]
# [1] ->FlipSort-> [1]
# [100, 101, 51, 41, 31, 21, 11, 1] ->FlipSort-> [1, 11, 21, 31, 41, 51, 100, 101]

# %% [markdown]
# # Problem 3 - Plot - 15 point
#
# Plot following 4 functions in a 2x2 subplots using `plt.subplot()` function.
#
# 1.   y = x
# 1.   y = x^2
# 1.   y = x^3
# 1.   y = sigmoid(x)

# %%
x = np.linspace(-2, 2, 30)
plt.subplot(2, 2, 1)
plt.plot(x, x)
# Update code here

plt.subplot(2, 2, 2)
plt.plot(x, x**2)

plt.subplot(2, 2, 3)
plt.plot(x, x**3)

plt.subplot(2, 2, 4)
plt.plot(x, 1/(1+np.exp(-x)))

plt.show()

# %% [markdown]
# :# Problem 4 - Implement Multiple Linear Regression from scratch - 50 points
#
# ## Overview
#
# In this problem, you will implement a **Multiple Linear Regression (MLR) model from scratch** (without bias) for a **Soundscape Emotion Recognition System**.
#
# ## Dataset:
#
# The dataset consists of:
#
# *   `arousal`: This is the ground truth (correct answer)
# *   **Other columns**: The rest of the columns are features to use to train MLR model
#
# You will use `test.csv` as the test set. **Do not modify this file**, as it will be used to compare the loss score across all students.
#
# Additionally, you must **split** `train.csv` **into training and validation sets** in a **90:10 ratio**. No further data processing is required.
#
# No further data processing is needed.
#
# ## Implementation details:
#
# *   Train and test the MLR model using the provided datasets: `Train.csv` and `Test.csv` (available on Canvas). These files contain pre-extracted and processed features from audio clips.
# *   Treat the `arousal` column as the **target variable** (in ML coding convension, this is called `y`), and all other columns as **input features** (in ML coding convension, this is called `X`)
# *   **Do not perform any additional data processing** on the dataset.
# *   Use **Stochastic Gradient Descent (SGD)** as the optimization algorithm.
# *   You should experiment with different **learning rates** and **number of training epochs** to minimize loss.
# *   While it is common to initialize the weight vector randomly, in this homework we require you to set it to the 0 vector.
# *   Plot the loss curve for both training and validation in a single graph (you can use `mathplotlib` or `seaborn` libraries for this)
# *   **Important:** you **CANNOT** use any machine learning libraries or packages like `sklearn` or `tensorflow` for this implementation. However, you may use `numpy` and/or `pandas` if needed.
#
# ## Submission Requirements:
#
# *   Make a copy of this colab, add your code, run all the cells, and save output. Submit your completed code as .ipynb file with output. Don't submit a link to your colab.
# *   Your submission must:
#   *   Successfully train the model and display test results.
#   *   Avoid runtime errors—points will be deducted for models that do not run correctly.
#   *   Clearly present the train, validation, and test loss, along with a loss curve plot for both training and validation.
# *   If your model fails to complete training, you will not receive full credit.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas
from random import randint
from sklearn.model_selection import train_test_split
# said we could use sklearn to split

train = pandas.read_csv('./train-1.csv')
test = pandas.read_csv('./test.csv')

# y = 0 column; x = 1 -> 68 columns; y = 0 -> 499 rows
x_train = train.drop(['arousal'], axis=1)
y_train = train['arousal']

# x_validate =
# y_validate =

x_test = test.drop(['arousal'], axis=1)
y_test = test['arousal']
# https://stackoverflow.com/questions/7588934/how-to-delete-columns-in-a-csv-file

x_train = np.array(x_train)
y_train = np.array(y_train)
x_test = np.array(x_test)
y_test = np.array(y_test)
# google says: np.array(data_list) for matrix multiplication

w = 0 # w_old
rate = 0.000000001
epochs = 100

training_loss_graph = []
validation_loss_graph = []

for i in range(0, epochs):
    # split the data between test and validation first
    split_x_train, split_x_validate = train_test_split(x_train, test_size=0.1, random_state=42)
    split_y_train, split_y_validate = train_test_split(y_train, test_size=0.1, random_state=42)

    for j in range(0, len(split_x_train)):
        prediction = split_x_train[j].dot(w) # xw
        # loss = # (y - mx)^2
        derivative = 2 * (split_y_train[j] - prediction) * (0 - 1*split_x_train[j]) # 2(y - mx) * (0 - 1*x)

        w = w - rate*derivative # w_new

    # after epoch, calculate the loss then add to graph list
    training_loss = np.mean((split_y_train - split_x_train.dot(w)) ** 2) # (y - mx)^2
    validation_loss = np.mean((split_y_validate - split_x_validate.dot(w)) ** 2) # (y - mx)^2
    test_loss = np.mean((y_test - x_test.dot(w)) ** 2) # (y - mx)^2

    training_loss_graph.append(training_loss)
    validation_loss_graph.append(validation_loss)

    print(f"Epoch {i}: Training Loss: {training_loss:.4f}, Validation Loss: {validation_loss:.4f}")

print(f"Final Test Loss: {test_loss:4f}")

plt.plot(range(epochs), training_loss_graph, label='Training Loss')
plt.plot(range(epochs), validation_loss_graph, label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss vs Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 0: Training Loss: 0.4208, Validation Loss: 0.4732
# Epoch 1: Training Loss: 0.3835, Validation Loss: 0.4355
# Epoch 2: Training Loss: 0.3576, Validation Loss: 0.4082
# Epoch 3: Training Loss: 0.3383, Validation Loss: 0.3871
# Epoch 4: Training Loss: 0.3234, Validation Loss: 0.3700
# Epoch 5: Training Loss: 0.3115, Validation Loss: 0.3559
# Epoch 6: Training Loss: 0.3019, Validation Loss: 0.3441
# Epoch 7: Training Loss: 0.2940, Validation Loss: 0.3339
# Epoch 8: Training Loss: 0.2873, Validation Loss: 0.3252
# Epoch 9: Training Loss: 0.2818, Validation Loss: 0.3175
# Epoch 10: Training Loss: 0.2771, Validation Loss: 0.3108
# Epoch 11: Training Loss: 0.2731, Validation Loss: 0.3049
# Epoch 12: Training Loss: 0.2696, Validation Loss: 0.2997
# Epoch 13: Training Loss: 0.2666, Validation Loss: 0.2951
# Epoch 14: Training Loss: 0.2640, Validation Loss: 0.2909
# Epoch 15: Training Loss: 0.2617, Validation Loss: 0.2872
# Epoch 16: Training Loss: 0.2597, Validation Loss: 0.2839
# Epoch 17: Training Loss: 0.2579, Validation Loss: 0.2809
# Epoch 18: Training Loss: 0.2564, Validation Loss: 0.2782
# Epoch 19: Training Loss: 0.2549, Validation Loss: 0.2758
# Epoch 20: Training Loss: 0.2537, Validation Loss: 0.2735
# Epoch 21: Training Loss: 0.2525, Validation Loss: 0.2715
# Epoch 22: Training Loss: 0.2515, Validation Loss: 0.2697
# Epoch 23: Training Loss: 0.2506, Validation Loss: 0.2679
# Epoch 24: Training Loss: 0.2497, Validation Loss: 0.2664
# Epoch 25: Training Loss: 0.2489, Validation Loss: 0.2649
# Epoch 26: Training Loss: 0.2482, Validation Loss: 0.2636
# Epoch 27: Training Loss: 0.2475, Validation Loss: 0.2623
# Epoch 28: Training Loss: 0.2468, Validation Loss: 0.2612
# Epoch 29: Training Loss: 0.2462, Validation Loss: 0.2601
# Epoch 30: Training Loss: 0.2457, Validation Loss: 0.2591
# Epoch 31: Training Loss: 0.2452, Validation Loss: 0.2581
# Epoch 32: Training Loss: 0.2447, Validation Loss: 0.2572
# Epoch 33: Training Loss: 0.2442, Validation Loss: 0.2564
# Epoch 34: Training Loss: 0.2437, Validation Loss: 0.2556
# Epoch 35: Training Loss: 0.2433, Validation Loss: 0.2548
# Epoch 36: Training Loss: 0.2429, Validation Loss: 0.2541
# Epoch 37: Training Loss: 0.2425, Validation Loss: 0.2534
# Epoch 38: Training Loss: 0.2421, Validation Loss: 0.2528
# Epoch 39: Training Loss: 0.2417, Validation Loss: 0.2521
# Epoch 40: Training Loss: 0.2414, Validation Loss: 0.2515
# Epoch 41: Training Loss: 0.2410, Validation Loss: 0.2509
# Epoch 42: Training Loss: 0.2407, Validation Loss: 0.2504
# Epoch 43: Training Loss: 0.2403, Validation Loss: 0.2498
# Epoch 44: Training Loss: 0.2400, Validation Loss: 0.2493
# Epoch 45: Training Loss: 0.2397, Validation Loss: 0.2488
# Epoch 46: Training Loss: 0.2394, Validation Loss: 0.2482
# Epoch 47: Training Loss: 0.2391, Validation Loss: 0.2478
# Epoch 48: Training Loss: 0.2388, Validation Loss: 0.2473
# Epoch 49: Training Loss: 0.2385, Validation Loss: 0.2468
# Epoch 50: Training Loss: 0.2382, Validation Loss: 0.2463
# Epoch 51: Training Loss: 0.2379, Validation Loss: 0.2459
# Epoch 52: Training Loss: 0.2376, Validation Loss: 0.2454
# Epoch 53: Training Loss: 0.2373, Validation Loss: 0.2450
# Epoch 54: Training Loss: 0.2371, Validation Loss: 0.2446
# Epoch 55: Training Loss: 0.2368, Validation Loss: 0.2441
# Epoch 56: Training Loss: 0.2365, Validation Loss: 0.2437
# Epoch 57: Training Loss: 0.2362, Validation Loss: 0.2433
# Epoch 58: Training Loss: 0.2360, Validation Loss: 0.2429
# Epoch 59: Training Loss: 0.2357, Validation Loss: 0.2425
# Epoch 60: Training Loss: 0.2355, Validation Loss: 0.2421
# Epoch 61: Training Loss: 0.2352, Validation Loss: 0.2417
# Epoch 62: Training Loss: 0.2349, Validation Loss: 0.2413
# Epoch 63: Training Loss: 0.2347, Validation Loss: 0.2409
# Epoch 64: Training Loss: 0.2344, Validation Loss: 0.2405
# Epoch 65: Training Loss: 0.2342, Validation Loss: 0.2401
# Epoch 66: Training Loss: 0.2339, Validation Loss: 0.2398
# Epoch 67: Training Loss: 0.2337, Validation Loss: 0.2394
# Epoch 68: Training Loss: 0.2334, Validation Loss: 0.2390
# Epoch 69: Training Loss: 0.2332, Validation Loss: 0.2386
# Epoch 70: Training Loss: 0.2329, Validation Loss: 0.2382
# Epoch 71: Training Loss: 0.2327, Validation Loss: 0.2379
# Epoch 72: Training Loss: 0.2324, Validation Loss: 0.2375
# Epoch 73: Training Loss: 0.2322, Validation Loss: 0.2371
# Epoch 74: Training Loss: 0.2319, Validation Loss: 0.2368
# Epoch 75: Training Loss: 0.2317, Validation Loss: 0.2364
# Epoch 76: Training Loss: 0.2314, Validation Loss: 0.2360
# Epoch 77: Training Loss: 0.2312, Validation Loss: 0.2357
# Epoch 78: Training Loss: 0.2310, Validation Loss: 0.2353
# Epoch 79: Training Loss: 0.2307, Validation Loss: 0.2350
# Epoch 80: Training Loss: 0.2305, Validation Loss: 0.2346
# Epoch 81: Training Loss: 0.2302, Validation Loss: 0.2342
# Epoch 82: Training Loss: 0.2300, Validation Loss: 0.2339
# Epoch 83: Training Loss: 0.2298, Validation Loss: 0.2335
# Epoch 84: Training Loss: 0.2295, Validation Loss: 0.2332
# Epoch 85: Training Loss: 0.2293, Validation Loss: 0.2328
# Epoch 86: Training Loss: 0.2290, Validation Loss: 0.2325
# Epoch 87: Training Loss: 0.2288, Validation Loss: 0.2321
# Epoch 88: Training Loss: 0.2286, Validation Loss: 0.2318
# Epoch 89: Training Loss: 0.2283, Validation Loss: 0.2314
# Epoch 90: Training Loss: 0.2281, Validation Loss: 0.2311
# Epoch 91: Training Loss: 0.2279, Validation Loss: 0.2307
# Epoch 92: Training Loss: 0.2276, Validation Loss: 0.2304
# Epoch 93: Training Loss: 0.2274, Validation Loss: 0.2300
# Epoch 94: Training Loss: 0.2272, Validation Loss: 0.2297
# Epoch 95: Training Loss: 0.2269, Validation Loss: 0.2294
# Epoch 96: Training Loss: 0.2267, Validation Loss: 0.2290
# Epoch 97: Training Loss: 0.2265, Validation Loss: 0.2287
# Epoch 98: Training Loss: 0.2262, Validation Loss: 0.2283
# Epoch 99: Training Loss: 0.2260, Validation Loss: 0.2280
# Final Test Loss: 0.162094
